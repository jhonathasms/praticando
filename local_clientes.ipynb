# %%
# Objetivo1
# O primeiro objetivo do projeto é plotar em um mapa, a distribuição de nossos clientes na cidade de Guarulhos
# Importar as bibliotecas necessárias para o desenvolvimento do projeto
import pandas as pd   #Biblioteca necessária para organizar os dados do .csv em linhas e colunas(tabulados)
import numpy as np    #Biblioteca necessária para se trabalhar com matrizes de n dimensões
import folium         #Biblioteca que nos permite utilizar o mapa para plotar nossos pontos
import random         #Biblioteca necessária para gerar números aleatórios

# %%
#Carregar os dados do dataset em .csv(neste caso) para uma tabela(dataframe)
clientes = pd.read_csv('clientes.csv')

# %%
#Mostrando a quantidade de dados no dataset
print('Este dataset contém {} linhas e {} colunas'.format(clientes.shape[0],clientes.shape[1]))
# Out:
# Este dataset contém 5000 linhas e 13 colunas

# %%
#Mostrar dados do dataset (03 primeiros)
clientes.head(3)
# Out:
#    Number GivenName   Surname  Gender                StreetAddress  \
# 0       1   Melissa     Silva  female          Rua José Maluf 1805
# 1       2      Kaua      Melo    male           Rua Padre Roma 868
# 2       3   Eduardo  Ferreira    male  Rua Fernando de Noronha 699
#
#                       City   StateFull    ZipCode TelephoneNumber  Age  \
# 0                São Paulo   São Paulo  02226-200  (11) 2816-2641   33
# 1  Jaboatão dos Guararapes  Pernambuco  54160-440  (81) 3519-2573   30
# 2        Francisco Beltrão      Paraná  85601-820  (46) 2926-4056   26
#
#          Company   Latitude  Longitude
# 0          Monit -23.673147 -46.542181
# 1       Thompson  -8.093942 -34.875021
# 2  Harvest Foods -26.100984 -53.062383

# %%
#Mostrar como o pandas está interpretando os dados
clientes.dtypes
# Out:
# Number               int64
# GivenName           object
# Surname             object
# Gender              object
# StreetAddress       object
# City                object
# StateFull           object
# ZipCode             object
# TelephoneNumber     object
# Age                  int64
# Company             object
# Latitude           float64
# Longitude          float64
# dtype: object

# %%
#Mostrar a descrição estatística dos dados númericos(interpretados pelo pandas)
clientes.describe()
# Out:
#             Number         Age     Latitude    Longitude
# count  5000.000000  5000.00000  5000.000000  5000.000000
# mean   2500.500000    31.44300   -19.242405   -45.923600
# std    1443.520003     8.04923     7.185220     5.196275
# min       1.000000    18.00000   -32.138543   -68.132763
# 25%    1250.750000    24.00000   -23.557897   -48.899268
# 50%    2500.500000    32.00000   -22.342137   -46.652148
# 75%    3750.250000    38.00000   -16.311875   -43.343168
# max    5000.000000    45.00000     3.273142   -34.765942

# %%
#Verificando se existem campos sem preenchimento
clientes.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Company            4
# Longitude          0
# Latitude           0
# Age                0
# TelephoneNumber    0
# ZipCode            0
# StateFull          0
# City               0
# StreetAddress      0
# Gender             0
# dtype: int64

# %%
#Mostrar os nomes das colunas
clientes.columns
# Out:
# Index(['Number', 'GivenName', 'Surname', 'Gender', 'StreetAddress', 'City',
#        'StateFull', 'ZipCode', 'TelephoneNumber', 'Age', 'Company', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
#Renomeando colunas para ficar mais didático
clientes.columns = ['Número', 'Nome', 'Sobrenome', 'Genero', 'Endereço',
                     'Cidade', 'Estado', 'CEP',
                     'Telefone', 'Idades', 'Empresa','Latitude','Longitude']

# %%
#Mostrar novo formato das colunas
clientes.columns
# Out:
# Index(['Número', 'Nome', 'Sobrenome', 'Genero', 'Endereço', 'Cidade', 'Estado',
#        'CEP', 'Telefone', 'Idades', 'Empresa', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#Mostrar os três primeiros dados com colunas renomeadas
clientes.head(3)
# Out:
#    Número     Nome Sobrenome  Genero                     Endereço  \
# 0       1  Melissa     Silva  female          Rua José Maluf 1805
# 1       2     Kaua      Melo    male           Rua Padre Roma 868
# 2       3  Eduardo  Ferreira    male  Rua Fernando de Noronha 699
#
#                     Cidade      Estado        CEP        Telefone  Idades  \
# 0                São Paulo   São Paulo  02226-200  (11) 2816-2641      33
# 1  Jaboatão dos Guararapes  Pernambuco  54160-440  (81) 3519-2573      30
# 2        Francisco Beltrão      Paraná  85601-820  (46) 2926-4056      26
#
#          Empresa   Latitude  Longitude
# 0          Monit -23.673147 -46.542181
# 1       Thompson  -8.093942 -34.875021
# 2  Harvest Foods -26.100984 -53.062383

# %%
#Excluindo colunas desnecessárias para o projeto (Opcional neste projeto) 
clientes.drop(['Sobrenome', 'Genero', 'Estado', 'CEP','Telefone', 'Idades', 'Empresa'],axis=1,inplace=True)

# %%
#Mostrar novo banco de dados sem dados desnecessários
clientes.head(3)
# Out:
#    Número     Nome                     Endereço                   Cidade  \
# 0       1  Melissa          Rua José Maluf 1805                São Paulo
# 1       2     Kaua           Rua Padre Roma 868  Jaboatão dos Guararapes
# 2       3  Eduardo  Rua Fernando de Noronha 699        Francisco Beltrão
#
#     Latitude  Longitude
# 0 -23.673147 -46.542181
# 1  -8.093942 -34.875021
# 2 -26.100984 -53.062383

# %%
#Criando uma nova dataframe somente com os clientes da cidade: "Guarulhos"
clientes_guarulhos = clientes[clientes['Cidade'] == 'Guarulhos']

# %%
#Visualizando DataFrame
clientes_guarulhos.head()
# Out:
#      Número     Nome                                           Endereço  \
# 26       27     Ryan                   Rua Santo Antônio do Paraíso 310
# 65       66    Clara  Rua Sargento da Aeronáutica da Benedito Fumeni...
# 73       74  Vitoria                     Rua Armando Arruda Pereira 838
# 202     203  Larissa                              Rua da Juventude 1877
# 284     285   Emilly                          Rua Jerônimo Monteiro 934
#
#         Cidade   Latitude  Longitude
# 26   Guarulhos -23.383449 -46.523581
# 65   Guarulhos -23.452123 -46.362001
# 73   Guarulhos -23.329813 -46.432172
# 202  Guarulhos -23.392773 -46.515911
# 284  Guarulhos -23.341047 -46.541464

# %%
#Mostrando a quantidade de linha e colunas no novo dataframe
print('O dataFrame com a cidade de Guarulhos contém: {} linhas e {} colunas'
      .format(clientes_guarulhos.shape[0],clientes_guarulhos.shape[1]))
# Out:
# O dataFrame com a cidade de Guarulhos contém: 50 linhas e 6 colunas

# %%
#Plotar a localização dos clientes de Guarulhos no mapa

#Variavel para gerar números aleatórios
numero_de_clientes = random.randint(random.randint(0,10),50)

#Variaveis para plotar o melhor local de entrega    
consulta = clientes_guarulhos[0:numero_de_clientes]
latitude = consulta['Latitude'].mean()
longitude = consulta['Longitude'].mean()

#Inserir latitude minima e longitude max dos clientes a serem mostrados no mapa
map = folium.Map(location=[clientes_guarulhos['Latitude'].min(), clientes_guarulhos['Longitude'].max()],zoom_start=10)

#Criando um loop para plotar cada cliente do conjunto de dados no mapa
for linha in clientes_guarulhos[0:numero_de_clientes].iterrows():
    folium.Marker([linha[1]['Latitude'], linha[1]['Longitude']], popup='Cliente: {}, Enderço: {}'.format
(linha[1]['Nome'],linha[1]['Endereço'])).add_to(map)
    
#Plotar o local médio para entrega aos clientes do conjunto de dados
folium.Marker([latitude, longitude],
              popup='Melhor Local de Entrega',
              icon=folium.Icon(color='red',icon='info-sign')
              ).add_to(map)

#Mostrar os clientes selecionados aleatóriamente
consulta
# Out:
#       Número       Nome                                           Endereço  \
# 26        27       Ryan                   Rua Santo Antônio do Paraíso 310
# 65        66      Clara  Rua Sargento da Aeronáutica da Benedito Fumeni...
# 73        74    Vitoria                     Rua Armando Arruda Pereira 838
# 202      203    Larissa                              Rua da Juventude 1877
# 284      285     Emilly                          Rua Jerônimo Monteiro 934
# 586      587      Aline                          Avenida Medeiros Neto 782
# 593      594      Julia                                Viela Alagoinhas 10
# 639      640      Pedro                                  Viela Iraque 1287
# 644      645      Júlio                            Rua Santa Terezinha 887
# 1076    1077    Gustavo                                 Rua Jaguaribe 1000
# 1175    1176     Sophia                                   Viela Egito 1492
# 1201    1202    Mariana                         Rua Quarto Centenario 1901
# 1549    1550     Evelyn                            Rua Santa Martinha 1601
# 1780    1781      Leila                         Rua Constantino Testa 1426
# 1846    1847     Yasmin                              Rua Altemar Dutra 626
# 1967    1968    Vitória                                        Rua Itu 733
# 2013    2014       João                           Avenida João Collado 106
# 2020    2021   Leonardo                            Rua Augusta Barbosa 446
# 2022    2023     Leonor                             Rua Coronel Macedo 874
# 2195    2196     Otávio                          Avenida Emílio Ribas 1087
# 2207    2208        Kai                         Rua Alvorada do Norte 1429
# 2273    2274  Gabrielle                                       Rua Huno 713
# 2292    2293   Beatrice                                 Rua Itanhandu 1921
#
#          Cidade   Latitude  Longitude
# 26    Guarulhos -23.383449 -46.523581
# 65    Guarulhos -23.452123 -46.362001
# 73    Guarulhos -23.329813 -46.432172
# 202   Guarulhos -23.392773 -46.515911
# 284   Guarulhos -23.341047 -46.541464
# 586   Guarulhos -23.314182 -46.514079
# 593   Guarulhos -23.447242 -46.483167
# 639   Guarulhos -23.378962 -46.518694
# 644   Guarulhos -23.400414 -46.370005
# 1076  Guarulhos -23.441243 -46.466094
# 1175  Guarulhos -23.388953 -46.443358
# 1201  Guarulhos -23.490204 -46.481337
# 1549  Guarulhos -23.480426 -46.358786
# 1780  Guarulhos -23.412131 -46.399163
# 1846  Guarulhos -23.340516 -46.401674
# 1967  Guarulhos -23.323613 -46.349109
# 2013  Guarulhos -23.392003 -46.421507
# 2020  Guarulhos -23.355101 -46.401781
# 2022  Guarulhos -23.322099 -46.435304
# 2195  Guarulhos -23.459348 -46.513718
# 2207  Guarulhos -23.434946 -46.440767
# 2273  Guarulhos -23.422692 -46.432314
# 2292  Guarulhos -23.364673 -46.524484

# %%
#Gerar mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
